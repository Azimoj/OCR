# %% [markdown]
# <a href="https://colab.research.google.com/github/Azimoj/OCR/blob/main/Extracting_Text_from_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.youtube.com/watch?v=JW3SLBOx_xc

# %%
# !pip install tesseract
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 MB 18.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tesseract: filename=tesseract-0.1.3-py3-none-any.whl size=45562550 sha256=ed2f67c04bfd16bc28f4f27e7e527d6df4b1efc8355a503c7b92e2e08d2c5373
#   Stored in directory: /root/.cache/pip/wheels/71/c9/aa/698c579693e83fdda9ad6d6f0d8f61ed986e27925ef576f109
# Successfully built tesseract
# ...

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd= r'c:\\programefile\\tesseract.exe'

# %%
import cv2

# %%
img= cv2.imread('1.png')
cv2.imshow('sample image', img)
cv2.waiteKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
text= pytesseract.image_to_string(img)
print(text)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
